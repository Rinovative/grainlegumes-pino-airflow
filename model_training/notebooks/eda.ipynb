# %%
import os

from src import eda, util

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # Disable GPU for EDA

# %%
# ---------------------------------------------------------
# DATASETS TO PROCESS
# ---------------------------------------------------------
dataset_names = [
    # "lhs_var10_plog100_seed1",
    # "lhs_var20_plog100_seed1001",
    # "lhs_var40_plog100_seed2001",
    # "lhs_var80_plog100_seed3001",
    # "lhs_var160_plog100_seed4001",
    ## V2 datasets with kappa-tensor, phi and p_bc inputs
    "lhs_var80_seed3001",
    "lhs_var120_seed4001",
    "lhs_var160_seed5001",
]

base_dir = "../../data/raw"

# ---------------------------------------------------------
# RUN EDA FOR ALL DATASETS
# ---------------------------------------------------------
datasets = {}
logs_all = {}

for name in dataset_names:
    print(f"\n[INFO] Processing EDA for dataset: {name}")
    df, logs = eda.eda_dataframe.generate_eda_dataframe(
        dataset_name=name,
        base_dir=base_dir,
        max_cases=250,
        show_progress=True,
    )
    datasets[name] = df
    logs_all[name] = logs

# %%
# ---------------------------------------------------------
# BUILD MULTI-DATASET TOGGLE
# ---------------------------------------------------------

toggle = util.util_nb.make_toggle_shortcut(datasets)

# ---------------------------------------------------------
# Build plots
# ---------------------------------------------------------

meta_plots = [
    toggle("1-1. Meta statistics", eda.eda_plot.eda_plot_case_statistics.plot_meta_statistics),
    toggle("1-2. Meta parameters", eda.eda_plot.eda_plot_case_statistics.plot_meta_parameters),
    toggle("1-3. Field value distributions", eda.eda_plot.eda_plot_case_statistics.plot_field_value_distributions),
]

spectral_plots = [
    toggle("2-1. Global", eda.eda_plot.eda_plot_spectral_analysis.plot_spectral_overview),
    toggle("2-2. Vertical evolution", eda.eda_plot.eda_plot_spectral_analysis.plot_spectral_vertical),
]

sections = [
    util.util_nb.make_dropdown_section(meta_plots),
    util.util_nb.make_dropdown_section(spectral_plots),
]

tab_titles = [
    "1. Meta & field statistics",
    "2. Spectral analysis",
]

# ---------------------------------------------------------
# Final Panel
# ---------------------------------------------------------

eda_panel = util.util_nb.make_lazy_panel_with_tabs(
    sections,
    tab_titles=tab_titles,
    open_btn_text="Open EDA",
    close_btn_text="Close",
)

display(eda_panel)
